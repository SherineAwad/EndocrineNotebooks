# %%
import csv
import sys
import re
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

# %% [markdown]
# # Plot pathways

# %% [markdown]
# # Same.dir = True and Unpaired

# %%
mpl.rcParams['savefig.dpi'] = 80
mpl.rcParams['figure.dpi'] = 80
y = [25,74,62,101,85,36,83,40,79,48,92,55,108,47,157,193,54,125,142,30,83,53,127,52,52,14,67,53,54,25]
x = np.arange(len(y))
columns =  ['hsa00534 Glycosaminoglycan biosynthesis - heparan sulfate','hsa04110 Cell cycle','hsa03440 Homologous recombination','hsa04914 Progesterone-mediated oocyte maturation','hsa03013 RNA transport','hsa04020 Calcium signaling pathway','hsa04730 Long-term depression','hsa03430 Mismatch repair','hsa00532 Glycosaminoglycan biosynthesis -chondroitinsulfate','hsa03008Ribosome biogenesis in eukaryotes','hsa03030 DNA replication','hsa01040 Biosynthesis of unsaturated fatty acids','hsa04122 Sulfur relay system','hsa03450 Non-homologous end-joining','hsa03020 RNA polymerase','hsa04360 Axon guidance','hsa02010 ABC transporters','hsa00670 One carbon pool by folate','hsa00020 Citrate cycle (TCA cycle)','hsa04540 Gap junction','hsa03022 Basal transcription factors','hsa04340 Hedgehog signaling pathway', 'hsa04512 ECM-receptor interaction','hsa00604 Glycosphingolipid biosynthesis - ganglio series','hsa04966 Collecting duct acid secretion','hsa00970 Aminoacyl-tRNA biosynthesis','hsa04964 Proximal tubule bicarbonate reclamation','hsa04971 Gastric acid secretion','hsa00250 Alanine, aspartate and glutamate metabolism','hsa04744 Phototransduction']

fig, ax = plt.subplots( )
ax.bar(x, y)
ax.set_xticks(x)
ax.set_xticklabels(columns)
plt.xticks(rotation=90)
plt.title('Pathways using Gage with same.dir equals True and Unpaired comparison')

fig.set_size_inches(11.7, 8.27)
plt.xlabel('KEGG Pathways')
plt.ylabel('GeneSet Size')
plt.show()
fig.savefig('pathways.png')

# %%
# Same.dir = False and Unpaired

# %%
y =[52,42,157,38,66,48,79,37,37,25,80,22,14,55,30,14]
x = np.arange(len(y))
columns = ['hsa00980 Metabolism of xenobiotics by cytochrome P450','hsa00830 Retinol metabolism','hsa04020 Calcium signaling pathway','hsa04672 Intestinal immune network for IgA production','hsa04974 Protein digestion and absorption','hsa04740 Olfactory transduction','hsa04640 Hematopoietic cell lineage','hsa00983 Drug metabolism - other enzymes','hsa00140 Steroid hormone biosynthesis','hsa00512 Mucin type O-Glycan biosynthesis','hsa04972 Pancreatic secretion','hsa00591 Linoleic acid metabolism','hsa00053 Ascorbate and aldarate metabolism','hsa04976 Bile secretion','hsa04742 Taste transduction','hsa00360 Phenylalanine metabolism']
fig, ax = plt.subplots( )
ax.bar(x, y)
ax.set_xticks(x)
ax.set_xticklabels(columns)
plt.xticks(rotation=90)
plt.title('Pathways using Gage with same.dir equals False and Unpaired comparison')

fig.set_size_inches(11.7, 8.27)
plt.xlabel('KEGG Pathways')
plt.ylabel('GeneSet Size')
plt.show()
fig.savefig('pathways.png')

# %%
import csv
import sys
import re
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

# %% [markdown]
# # Plot pathways

# %% [markdown]
# # Same.dir = True and Unpaired

# %%
mpl.rcParams['savefig.dpi'] = 80
mpl.rcParams['figure.dpi'] = 80
y = [25,74,62,101,85,36,83,40,79,48,92,55,108,47,157,193,54,125,142,30,83,53,127,52,52,14,67,53,54,25]
x = np.arange(len(y))
columns =  ['hsa00534 Glycosaminoglycan biosynthesis - heparan sulfate','hsa04110 Cell cycle','hsa03440 Homologous recombination','hsa04914 Progesterone-mediated oocyte maturation','hsa03013 RNA transport','hsa04020 Calcium signaling pathway','hsa04730 Long-term depression','hsa03430 Mismatch repair','hsa00532 Glycosaminoglycan biosynthesis -chondroitinsulfate','hsa03008Ribosome biogenesis in eukaryotes','hsa03030 DNA replication','hsa01040 Biosynthesis of unsaturated fatty acids','hsa04122 Sulfur relay system','hsa03450 Non-homologous end-joining','hsa03020 RNA polymerase','hsa04360 Axon guidance','hsa02010 ABC transporters','hsa00670 One carbon pool by folate','hsa00020 Citrate cycle (TCA cycle)','hsa04540 Gap junction','hsa03022 Basal transcription factors','hsa04340 Hedgehog signaling pathway', 'hsa04512 ECM-receptor interaction','hsa00604 Glycosphingolipid biosynthesis - ganglio series','hsa04966 Collecting duct acid secretion','hsa00970 Aminoacyl-tRNA biosynthesis','hsa04964 Proximal tubule bicarbonate reclamation','hsa04971 Gastric acid secretion','hsa00250 Alanine, aspartate and glutamate metabolism','hsa04744 Phototransduction']

fig, ax = plt.subplots( )
ax.bar(x, y)
ax.set_xticks(x)
ax.set_xticklabels(columns)
plt.xticks(rotation=90)
plt.title('Pathways using Gage with same.dir equals True and Unpaired comparison')

fig.set_size_inches(11.7, 8.27)
plt.xlabel('KEGG Pathways')
plt.ylabel('GeneSet Size') 
plt.show()
fig.savefig('pathways_true_genes.png',papertype='letter', bbox_inches= 'tight', dpi=600)

# %%
# Same.dir = False and Unpaired

# %%
y =[52,42,157,38,66,48,79,37,37,25,80,22,14,55,30,14]
x = np.arange(len(y))
columns = ['hsa00980 Metabolism of xenobiotics by cytochrome P450','hsa00830 Retinol metabolism','hsa04020 Calcium signaling pathway','hsa04672 Intestinal immune network for IgA production','hsa04974 Protein digestion and absorption','hsa04740 Olfactory transduction','hsa04640 Hematopoietic cell lineage','hsa00983 Drug metabolism - other enzymes','hsa00140 Steroid hormone biosynthesis','hsa00512 Mucin type O-Glycan biosynthesis','hsa04972 Pancreatic secretion','hsa00591 Linoleic acid metabolism','hsa00053 Ascorbate and aldarate metabolism','hsa04976 Bile secretion','hsa04742 Taste transduction','hsa00360 Phenylalanine metabolism']
fig, ax = plt.subplots( )
ax.bar(x, y)
ax.set_xticks(x)
ax.set_xticklabels(columns)
plt.xticks(rotation=90)
plt.title('Pathways using Gage with same.dir equals False and Unpaired comparison')

fig.set_size_inches(11.7, 8.27)
plt.xlabel('KEGG Pathways')
plt.ylabel('GeneSet Size')
plt.show()
fig.savefig('pathways_false_genes.png',papertype='letter' , bbox_inches= 'tight', dpi=600)

# %%
y =[1.91067408961101,-4.52188048474045,-4.14708721922629,-4.06507622786449,-3.90367658266735,-3.87547781208793,-3.72578178460979,-3.64478783316511,-3.52406917325336,-3.50935477066657,-3.37569339941202,-3.28938085611475,-3.20412602896115,-3.23471785534514,-3.0916521842293,-3.02425181026717,-3.00683417584983,-2.87252174893122,-2.71458809508119,-2.74270861606399,-2.69733255021786,-2.67802889479682,-2.63042078529779,-2.61956071239927,-2.60545665198527,-2.73020149261465,-2.53698422402848,-2.35154668592377,-2.32940675454707,-2.37289021399426]
x = np.arange(len(y))
columns =  ['hsa00534 Glycosaminoglycan biosynthesis - heparan sulfate','hsa04110 Cell cycle','hsa03440 Homologous recombination','hsa04914 Progesterone-mediated oocyte maturation','hsa03013 RNA transport','hsa04020 Calcium signaling pathway','hsa04730 Long-term depression','hsa03430 Mismatch repair','hsa00532 Glycosaminoglycan biosynthesis -chondroitinsulfate','hsa03008Ribosome biogenesis in eukaryotes','hsa03030 DNA replication','hsa01040 Biosynthesis of unsaturated fatty acids','hsa04122 Sulfur relay system','hsa03450 Non-homologous end-joining','hsa03020 RNA polymerase','hsa04360 Axon guidance','hsa02010 ABC transporters','hsa00670 One carbon pool by folate','hsa00020 Citrate cycle (TCA cycle)','hsa04540 Gap junction','hsa03022 Basal transcription factors','hsa04340 Hedgehog signaling pathway', 'hsa04512 ECM-receptor interaction','hsa00604 Glycosphingolipid biosynthesis - ganglio series','hsa04966 Collecting duct acid secretion','hsa00970 Aminoacyl-tRNA biosynthesis','hsa04964 Proximal tubule bicarbonate reclamation','hsa04971 Gastric acid secretion','hsa00250 Alanine, aspartate and glutamate metabolism','hsa04744 Phototransduction']
fig, ax = plt.subplots( )
ax.bar(x, y)
ax.set_xticks(x)
ax.set_xticklabels(columns)
plt.xticks(rotation=90)
plt.title('Pathways using Gage with same.dir equals True and Unpaired comparison')

fig.set_size_inches(11.7, 8.27)
plt.xlabel('KEGG Pathways')
plt.ylabel('Stats.Mean')
plt.show()
fig.savefig('pathways_true_mean.png',papertype='letter' , bbox_inches= 'tight', dpi=600)

# %%
y =[3.85367625541425,3.27884062464516,3.15472228810499,2.98894202903998,2.72451910003615,2.53397071786015,2.49043892658748,2.45367658860282,2.35605073836204,2.11096467682521,2.05448429124885,2.00230731855419,1.94136622107934,1.84216317326828,1.8372272926474,1.79807604135063]
x = np.arange(len(y))
columns = ['hsa00980 Metabolism of xenobiotics by cytochrome P450','hsa00830 Retinol metabolism','hsa04020 Calcium signaling pathway','hsa04672 Intestinal immune network for IgA production','hsa04974 Protein digestion and absorption','hsa04740 Olfactory transduction','hsa04640 Hematopoietic cell lineage','hsa00983 Drug metabolism - other enzymes','hsa00140 Steroid hormone biosynthesis','hsa00512 Mucin type O-Glycan biosynthesis','hsa04972 Pancreatic secretion','hsa00591 Linoleic acid metabolism','hsa00053 Ascorbate and aldarate metabolism','hsa04976 Bile secretion','hsa04742 Taste transduction','hsa00360 Phenylalanine metabolism']
fig, ax = plt.subplots( )
ax.bar(x, y)
ax.set_xticks(x)
ax.set_xticklabels(columns)
plt.xticks(rotation=90)
plt.title('Pathways using Gage with same.dir equals False and Unpaired comparison')

fig.set_size_inches(11.7, 8.27)
plt.xlabel('KEGG Pathways')
plt.ylabel('Stats.Mean')
plt.show()
fig.savefig('pathways_false_mean.png',papertype='letter' , bbox_inches= 'tight', dpi=600)

# %%
y = [130,125,127,161,94,132,181,192,484,67,472,493,461,386,419,472,496,432,325,315]
x = np.arange(len(y))
columns = ['GO:0007156 homophilic cell adhesion','GO:0006836 neurotransmitter transport','GO:0001505 regulation of neurotransmitter levels','GO:0050804 regulation of synaptic transmission','GO:0007269neurotransmitter secretion','GO:0050808 synapse organization','GO:0051969 regulation of transmission of nerve impulse','GO:0031644 regulation of neurological system process','GO:0007409 axonogenesis','GO:0007416 synapse assembly','GO:0050776 regulation of immune response','GO:0002684 positive regulation of immune system process','GO:0045087 innate immune response','GO:0002252 immune effector process','GO:0006954 inflammatory response','GO:0051707 response to other organism','GO:0009607 response to biotic stimulus','GO:0046649 lymphocyte activation','GO:0050778 positive regulation of immune response','GO:0042110 T cell activation']
fig, ax = plt.subplots( )
ax.bar(x, y)
ax.set_xticks(x)
ax.set_xticklabels(columns)
plt.xticks(rotation=90)
plt.title('Top 20 GO terms using Gage with same.dir equals True and Unpaired comparison')

fig.set_size_inches(11.7, 8.27)
plt.xlabel('GO terms: Biological Process')
plt.ylabel('GeneSet Size')
plt.show()
fig.savefig('GO_True_gene.png',papertype='letter' , bbox_inches= 'tight', dpi=600)

# %%
y =[470,130,382,308,308,388,363,456,125,458,322,127,400,249,192,179,181,107,161,108]
x = np.arange(len(y))
columns= ['GO:0007186 G-protein coupled receptor signaling pathway','GO:0007156 homophilic cell adhesion','GO:0016337 cell-cell adhesion','GO:0003001 generation of a signal involved in cell-cell signaling','GO:0023061 signal release','GO:0051046 regulation of secretion','GO:0007600 sensory perception','GO:0030001 metal ion transport','GO:0006836 neurotransmitter transport','GO:0007610 behavior','GO:0010817 regulation of hormone levels','GO:0001505 regulation of neurotransmitter levels','GO:0044057 regulation of system process','GO:0030900 forebrain development','GO:0031644 regulation of neurological system process','GO:0045165 cell fate commitment','GO:0051969 regulation of transmission of nerve impulse','GO:0006813 potassium ion transport','GO:0050804 regulation of synaptic transmission','GO:0021953 central nervous system neuron differentiation']
fig, ax = plt.subplots( )
ax.bar(x, y)
ax.set_xticks(x)
ax.set_xticklabels(columns)
plt.xticks(rotation=90)
plt.title('Top 20 GO terms using Gage with same.dir equals False and Unpaired comparison')

fig.set_size_inches(11.7, 8.27)
plt.xlabel('GO terms: Biological Process')
plt.ylabel('GeneSet Size')
plt.show()
fig.savefig('GO_False_genes.png',papertype='letter' , bbox_inches= 'tight', dpi=600)

# %%
y = [4.93286098310043,4.93113735510029,4.58605575272178,4.4388581619703,4.36663483026617,4.22868573981474,3.9293340307994,3.91941467374173,3.83310103109021,3.88102956968201,-11.9641370825777,-11.5648058662526,-10.7579806577348,-10.8065863703492,-10.6551120948325,-10.5313525879429,-10.4500703711047,-9.8041020125508,-9.79811294053016,-9.36606177715379]
x = np.arange(len(y))
columns = ['GO:0007156 homophilic cell adhesion','GO:0006836 neurotransmitter transport','GO:0001505 regulation of neurotransmitter levels','GO:0050804 regulation of synaptic transmission','GO:0007269neurotransmitter secretion','GO:0050808 synapse organization','GO:0051969 regulation of transmission of nerve impulse','GO:0031644 regulation of neurological system process','GO:0007409 axonogenesis','GO:0007416 synapse assembly','GO:0050776 regulation of immune response','GO:0002684 positive regulation of immune system process','GO:0045087 innate immune response','GO:0002252 immune effector process','GO:0006954 inflammatory response','GO:0051707 response to other organism','GO:0009607 response to biotic stimulus','GO:0046649 lymphocyte activation','GO:0050778 positive regulation of immune response','GO:0042110 T cell activation']
fig, ax = plt.subplots( )
ax.bar(x, y)
ax.set_xticks(x)
ax.set_xticklabels(columns)
plt.xticks(rotation=90)
plt.title('Top 20 GO terms using Gage with same.dir equals True and Unpaired comparison')

fig.set_size_inches(11.7, 8.27)
plt.xlabel('GO terms: Biological Process')
plt.ylabel('Stats.Mean')
plt.show()
fig.savefig('GO_True_mean.png',papertype='letter' , bbox_inches= 'tight', dpi=600)

# %%
y =[6.22034645062793,5.61722490853909,5.17167557507754,4.91273551776916,4.91273551776916,4.89167323570332,4.85326721302026,4.65768691822451,4.7067713192926,4.53040292783565,4.46060944759764,4.48013422590645,4.35347098436467,4.18640498279086,4.19371130288384,4.12651623775317,4.08382029453622,4.10362473394596,3.96386772581732,3.97071253502427]
x = np.arange(len(y))
columns= ['GO:0007186 G-protein coupled receptor signaling pathway','GO:0007156 homophilic cell adhesion','GO:0016337 cell-cell adhesion','GO:0003001 generation of a signal involved in cell-cell signaling','GO:0023061 signal release','GO:0051046 regulation of secretion','GO:0007600 sensory perception','GO:0030001 metal ion transport','GO:0006836 neurotransmitter transport','GO:0007610 behavior','GO:0010817 regulation of hormone levels','GO:0001505 regulation of neurotransmitter levels','GO:0044057 regulation of system process','GO:0030900 forebrain development','GO:0031644 regulation of neurological system process','GO:0045165 cell fate commitment','GO:0051969 regulation of transmission of nerve impulse','GO:0006813 potassium ion transport','GO:0050804 regulation of synaptic transmission','GO:0021953 central nervous system neuron differentiation']
fig, ax = plt.subplots( )
ax.bar(x, y)
ax.set_xticks(x)
ax.set_xticklabels(columns)
plt.xticks(rotation=90)
plt.title('Top 20 GO terms using Gage with same.dir equals False and Unpaired comparison')

fig.set_size_inches(11.7, 8.27)
plt.xlabel('GO terms: Biological Process')
plt.ylabel('Stats.Mean')
plt.show()
fig.savefig('GO_False_mean.png',papertype='letter' , bbox_inches= 'tight', dpi=600)

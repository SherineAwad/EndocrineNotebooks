# %%
import csv

def load_file(filename):
    with open(filename) as f:
        lines = f.readlines()
    genes =[]
    for i in lines:
        genes.append( i.rstrip().upper() )
    return genes

# %%
list1 = load_file('f449.genes')
list2 = load_file('genes.intellectual')


for i in list2:
        if i in list1: 
                print i
# Out:
# ALX4
# APC2
# BBS5
# EXT2
# HOXA1
# LRP2
# MKS1
# RAB23
# SEMA3E
# TFAP2B
# WNT5A
# ACTB
# ADNP
# ARID1A
# ATP6V1B2
# BRF1
# CHRNA1
# COLEC11
# FLNB
# MAP2K2
# MTHFR
# MTOR
# NEU1
# NSUN2
# PIGL
# PPP2R5D
# PTRH2
# RAI1
# SOX11
# SRCAP

# %%
#Filter 449 Excel genes list of 454
fp = open('f449.genes', 'w+')
with open('f449.genes.list') as f: 
        lines =f.readlines() 
        for i in lines: 
                line = i.split(',')
                gene = line[-1].strip().split(' ')
                print >>fp, gene[-1]
                print gene[-1]
               
print 'Done'

# %%
#Filter genes.intellectual
fp = open('genes.intellectual', 'w+')
with open('genes.intellectual.list') as f: 
        lines =f.readlines() 
        for i in lines: 
             line = i.split('-')
             print line[-1].strip()
             print >>fp, line[-1].strip() 
print 'Done'
# Out:
# A2ML1
# ABCC9
# ALX4
# APC2
# ARL6
# ARVCF
# BBIP1
# BBS1
# BBS10
# BBS12
# BBS2
# BBS4
# BBS5
# BBS7
# BBS9
# BCOR
# BRAF
# BRCC3
# C8ORF37
# CC2D2A
# CDC45
# CDC6
# CDKN1C
# CDT1
# CEP290
# CHD7
# COMT
# DPP6
# DVL1
# DVL3
# EXT2
# FGD1
# FGFR2
# FLNA
# FREM1
# GJA1
# GLI3
# GMNN
# GP1BB
# H19
# HIRA
# HOXA1
# IFT172
# IFT27
# IGF2
# INPP5E
# IRF6
# JMJD1C
# KAT6B
# KCNJ8
# KRAS
# LMNA
# LRP2
# LZTFL1
# LZTR1
# MAGEL2
# MAP3K7
# MEGF8
# MIR17HG
# MKKS
# MKS1
# MYCN
# NAA10
# NDN
# NFIA
# NFIX
# NHS
# NPHP1
# NRAS
# NSD1
# OCA2
# ORC1
# ORC4
# ORC6
# PHF21A
# PIK3R1
# PLXND1
# PORCN
# PTPN11
# RAB23
# RAF1
# RASA2
# REV3L
# RIT1
# ROR2
# RPGRIP1L
# RREB1
# RYR1
# SDCCAG8
# SEC24C
# SEMA3E
# SETBP1
# SETD2
# SHOC2
# SIM1
# SMO
# SMOC1
# SNORD115@
# SNORD116@
# SNRPB
# SNRPN
# SOS1
# SOS2
# SOX2
# SOX9
# TBX1
# TBX3
# TFAP2B
# TMEM67
# TRIM32
# TTC8
# TWIST2
# UFD1L
# WDPCP
# WNT5A
# ZMPSTE24
# intellectual disability
# ACSL4
# ACTB
# ACTG1
# ADNP
# AFF4
# AMMECR1
# ANKRD11
# ANTXR1
# ...

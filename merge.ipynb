# %%
import csv
import sys
import re
import numpy as np; 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns;

# %%
families= []
marta = [] 
gnomad = []
diff = []
fp1 = open('marta.aip.txt', 'r')
for line1 in fp1.readlines():
    marta.append(line1.upper().strip())

fp2 = open('gnomad.aip.txt', 'r')
for  line2 in fp2.readlines():
    gnomad.append(line1.upper().strip())
         
for i in marta: 
    if i not in gnomad: 
        diff.append(i)
count = 0
for i in diff: 
    count +=1
    print i
print(count, 'Done')
# Out:
# G.3028T>G
# G.3134C>A
# G.3173DELA
# G.3173A>T
# G.3394C>T
# G.3466C>T
# G.3651T>G
# G.3716C>T
# G.3730C>A
# G.3792T>A
# G.3893C>T
# G.4085A>G
# G.4108G>A
# G.4190T>C
# G.4236C>T
# G.4256A>C
# G.4274A>C
# G.4310T>A
# G.4314T>G
# G.4323DELT
# G.4323T>G
# G.4407C>G
# G.4623C>T
# G.4727DELT
# G.4785DELC
# G.4825T>C
# G.4864G>A
# G.4906G>A
# G.4939C>G
# G.4960G>A
# C.-86G>A
# C.-77C>G
# C.-57T>C
# C.-23A>G
# C.-13G>A
# C.-5G>C
# C.-2G>A
# C.2T>C
# C.3G>A
# C.26G>A
# C.26G>T
# C.36G>A
# C.38T>A
# C.40C>T
# C.47G>A
# C.52A>G
# C.58G>T
# C.63C>T
# C.64C>T
# C.68G>A
# C.70G>T
# C.72G>C
# C.75C>T
# C.84T>C
# C.90T>C
# C.90T>G
# C.93G>T
# C.99+9C>T
# C.99+10T>C
# C.99+25C>T
# C.99+27C>G
# C.99+38T>G
# C.99+178T>G
# C.99+185C>T
# C.99+305G>T
# C.99+306C>T
# C.99+307C>T
# C.99+526T>C
# C.99+550T>C
# C.99+574G>C
# C.99+692G>A
# C.99+694C>T
# C.99+726A>G
# C.99+750G>A
# C.99+950G>A
# C.99+1091C>G
# C.99+1127A>G
# C.99+1271C>T
# C.99+1330C>T
# C.99+1341A>G
# C.99+1446A>G
# C.99+1449G>T
# ...
